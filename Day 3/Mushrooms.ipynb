# %%
import pandas as pd

# %%
df=pd.read_csv('mushrooms.csv')

# %%
df.head()
# Out:
#   class cap-shape cap-surface  ... spore-print-color population habitat
# 0     p         x           s  ...                 k          s       u
# 1     e         x           s  ...                 n          n       g
# 2     e         b           s  ...                 n          n       m
# 3     p         x           y  ...                 k          s       u
# 4     e         x           s  ...                 n          a       g
#
# [5 rows x 23 columns]

# %%
df.shape
# Out:
# (8124, 23)

# %%
df.columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %%
df['class'].unique()
# Out:
# array(['p', 'e'], dtype=object)

# %%
from sklearn import preprocessing 
label_encoder = preprocessing.LabelEncoder() 
df=df.apply(label_encoder.fit_transform)

# %%
df.head()
# Out:
#    class  cap-shape  cap-surface  ...  spore-print-color  population  habitat
# 0      1          5            2  ...                  2           3        5
# 1      0          5            2  ...                  3           2        1
# 2      0          0            2  ...                  3           2        3
# 3      1          5            3  ...                  2           3        5
# 4      0          5            2  ...                  3           0        1
#
# [5 rows x 23 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
fig, (ax) = plt.subplots(1, 1, figsize=(25,10))
sns.heatmap(df.corr(), ax=ax,cmap="coolwarm",annot=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
fig, axs = plt.subplots(4, 5,figsize=(25,12))
df_1=df[df['class']==1]
df_0=df[df['class']==0]
sns.kdeplot(df_0['cap-shape'],label='cap-shape e',ax=axs[0,0])
sns.kdeplot(df_1['cap-shape'],label='cap-shape p',ax=axs[0,0])
sns.kdeplot(df_0['cap-surface'],label='cap-surface e',ax=axs[0,1])
sns.kdeplot(df_1['cap-surface'],label='cap-surface p',ax=axs[0,1])
sns.kdeplot(df_0['cap-color'],label='cap-color e',ax=axs[0,2])
sns.kdeplot(df_1['cap-color'],label='cap-color p',ax=axs[0,2])
sns.kdeplot(df_0['bruises'],label='bruises e',ax=axs[0,3])
sns.kdeplot(df_1['bruises'],label='bruises p',ax=axs[0,3])
sns.kdeplot(df_0['odor'],label='odor e',ax=axs[0,4])
sns.kdeplot(df_1['odor'],label='odor p',ax=axs[0,4])
sns.kdeplot(df_0['gill-spacing'],label='gill-spacing e',ax=axs[1,0])
sns.kdeplot(df_1['gill-spacing'],label='gill-spacing p',ax=axs[1,0])
sns.kdeplot(df_0['gill-size'],label='gill-size e',ax=axs[1,1])
sns.kdeplot(df_1['gill-size'],label='gill-size p',ax=axs[1,1])
sns.kdeplot(df_0['gill-color'],label='gill-color e',ax=axs[1,2])
sns.kdeplot(df_1['gill-color'],label='gill-color p',ax=axs[1,2])
sns.kdeplot(df_0['stalk-shape'],label='stalk-shape e',ax=axs[1,3])
sns.kdeplot(df_1['stalk-shape'],label='stalk-shape p',ax=axs[1,3])
sns.kdeplot(df_0['stalk-root'],label='stalk-root e',ax=axs[1,4])
sns.kdeplot(df_1['stalk-root'],label='stalk-root p',ax=axs[1,4])
sns.kdeplot(df_0['stalk-surface-above-ring'],label='stalk-surface-above-ring e',ax=axs[2,0])
sns.kdeplot(df_1['stalk-surface-above-ring'],label='stalk-surface-above-ring p',ax=axs[2,0])
sns.kdeplot(df_0['stalk-surface-below-ring'],label='stalk-surface-below-ring e',ax=axs[2,1])
sns.kdeplot(df_1['stalk-surface-below-ring'],label='stalk-surface-below-ring p',ax=axs[2,1])
sns.kdeplot(df_0['stalk-color-above-ring'],label='stalk-color-above-ring e',ax=axs[2,2])
sns.kdeplot(df_1['stalk-color-above-ring'],label='stalk-color-above-ring p',ax=axs[2,2])
sns.kdeplot(df_0['stalk-color-below-ring'],label='stalk-color-below-ring e',ax=axs[2,3])
sns.kdeplot(df_1['stalk-color-below-ring'],label='stalk-color-below-ring p',ax=axs[2,3])
sns.kdeplot(df_0['veil-color'],label='veil-color e',ax=axs[2,4])
sns.kdeplot(df_1['veil-color'],label='veil-color p',ax=axs[2,4])
sns.kdeplot(df_0['ring-number'],label='ring-number e',ax=axs[3,0])
sns.kdeplot(df_1['ring-number'],label='ring-number p',ax=axs[3,0])
sns.kdeplot(df_0['ring-type'],label='ring-type e',ax=axs[3,1])
sns.kdeplot(df_1['ring-type'],label='ring-type p',ax=axs[3,1])
sns.kdeplot(df_0['spore-print-color'],label='spore-print-color e',ax=axs[3,2])
sns.kdeplot(df_1['spore-print-color'],label='spore-print-color p',ax=axs[3,2])
sns.kdeplot(df_0['population'],label='population e',ax=axs[3,3])
sns.kdeplot(df_1['population'],label='population p',ax=axs[3,3])
sns.kdeplot(df_0['habitat'],label='habitat e',ax=axs[3,4])
sns.kdeplot(df_1['habitat'],label='habitat p',ax=axs[3,4])

# %%
fig, axs = plt.subplots(4, 5,figsize=(25,12))

sns.kdeplot(df_0.corr()['cap-shape'],label='cap-shape e',ax=axs[0,0])
sns.kdeplot(df_1.corr()['cap-shape'],label='cap-shape p',ax=axs[0,0])
sns.kdeplot(df_0.corr()['cap-surface'],label='cap-surface e',ax=axs[0,1])
sns.kdeplot(df_1.corr()['cap-surface'],label='cap-surface p',ax=axs[0,1])
sns.kdeplot(df_0.corr()['cap-color'],label='cap-color e',ax=axs[0,2])
sns.kdeplot(df_1.corr()['cap-color'],label='cap-color p',ax=axs[0,2])
sns.kdeplot(df_0.corr()['bruises'],label='bruises e',ax=axs[0,3])
sns.kdeplot(df_1.corr()['bruises'],label='bruises p',ax=axs[0,3])
sns.kdeplot(df_0.corr()['odor'],label='odor e',ax=axs[0,4])
sns.kdeplot(df_1.corr()['odor'],label='odor p',ax=axs[0,4])
sns.kdeplot(df_0.corr()['gill-spacing'],label='gill-spacing e',ax=axs[1,0])
sns.kdeplot(df_1.corr()['gill-spacing'],label='gill-spacing p',ax=axs[1,0])
sns.kdeplot(df_0.corr()['gill-size'],label='gill-size e',ax=axs[1,1])
sns.kdeplot(df_1.corr()['gill-size'],label='gill-size p',ax=axs[1,1])
sns.kdeplot(df_0.corr()['gill-color'],label='gill-color e',ax=axs[1,2])
sns.kdeplot(df_1.corr()['gill-color'],label='gill-color p',ax=axs[1,2])
sns.kdeplot(df_0.corr()['stalk-shape'],label='stalk-shape e',ax=axs[1,3])
sns.kdeplot(df_1.corr()['stalk-shape'],label='stalk-shape p',ax=axs[1,3])
sns.kdeplot(df_0.corr()['stalk-root'],label='stalk-root e',ax=axs[1,4])
sns.kdeplot(df_1.corr()['stalk-root'],label='stalk-root p',ax=axs[1,4])
sns.kdeplot(df_0.corr()['stalk-surface-above-ring'],label='stalk-surface-above-ring e',ax=axs[2,0])
sns.kdeplot(df_1.corr()['stalk-surface-above-ring'],label='stalk-surface-above-ring p',ax=axs[2,0])
sns.kdeplot(df_0.corr()['stalk-surface-below-ring'],label='stalk-surface-below-ring e',ax=axs[2,1])
sns.kdeplot(df_1.corr()['stalk-surface-below-ring'],label='stalk-surface-below-ring p',ax=axs[2,1])
sns.kdeplot(df_0.corr()['stalk-color-above-ring'],label='stalk-color-above-ring e',ax=axs[2,2])
sns.kdeplot(df_1.corr()['stalk-color-above-ring'],label='stalk-color-above-ring p',ax=axs[2,2])
sns.kdeplot(df_0.corr()['stalk-color-below-ring'],label='stalk-color-below-ring e',ax=axs[2,3])
sns.kdeplot(df_1.corr()['stalk-color-below-ring'],label='stalk-color-below-ring p',ax=axs[2,3])
sns.kdeplot(df_0.corr()['veil-color'],label='veil-color e',ax=axs[2,4])
sns.kdeplot(df_1.corr()['veil-color'],label='veil-color p',ax=axs[2,4])
sns.kdeplot(df_0.corr()['ring-number'],label='ring-number e',ax=axs[3,0])
sns.kdeplot(df_1.corr()['ring-number'],label='ring-number p',ax=axs[3,0])
sns.kdeplot(df_0.corr()['ring-type'],label='ring-type e',ax=axs[3,1])
sns.kdeplot(df_1.corr()['ring-type'],label='ring-type p',ax=axs[3,1])
sns.kdeplot(df_0.corr()['spore-print-color'],label='spore-print-color e',ax=axs[3,2])
sns.kdeplot(df_1.corr()['spore-print-color'],label='spore-print-color p',ax=axs[3,2])
sns.kdeplot(df_0.corr()['population'],label='population e',ax=axs[3,3])
sns.kdeplot(df_1.corr()['population'],label='population p',ax=axs[3,3])
sns.kdeplot(df_0.corr()['habitat'],label='habitat e',ax=axs[3,4])
sns.kdeplot(df_1.corr()['habitat'],label='habitat p',ax=axs[3,4])

# %%
X=df[[ 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
       'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
       'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
       'stalk-surface-below-ring', 'stalk-color-above-ring',
       'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
       'ring-type', 'spore-print-color', 'population', 'habitat']]
Y=df['class']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.25,random_state = 0)

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(random_state=0,max_depth=3)
clf.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=3, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=0, verbose=0,
#                        warm_start=False)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(Y_test,clf.predict(X_test))
# Out:
# 0.9778434268833087

# %%
from sklearn.metrics import classification_report
classificationReport= classification_report(Y_test, clf.predict(X_test), target_names=['e','p'], )
print(classificationReport)
# Out:
#               precision    recall  f1-score   support
#
#            e       0.97      0.99      0.98      1061
#            p       0.99      0.96      0.98       970
#
#     accuracy                           0.98      2031
#    macro avg       0.98      0.98      0.98      2031
# weighted avg       0.98      0.98      0.98      2031

# %%
a=pd.DataFrame(data={'names':X.columns,'values':clf.feature_importances_}).sort_values('values',ascending=False)
a
# Out:
#                        names    values
# 7                  gill-size  0.128418
# 4                       odor  0.116056
# 8                 gill-color  0.100473
# 18                 ring-type  0.089339
# 3                    bruises  0.085478
# 19         spore-print-color  0.082376
# 20                population  0.077222
# 11  stalk-surface-above-ring  0.071840
# 6               gill-spacing  0.056416
# 12  stalk-surface-below-ring  0.053726
# 10                stalk-root  0.042995
# 21                   habitat  0.025198
# 14    stalk-color-below-ring  0.023750
# 13    stalk-color-above-ring  0.013770
# 17               ring-number  0.011272
# 9                stalk-shape  0.007806
# 1                cap-surface  0.004879
# 16                veil-color  0.004538
# 2                  cap-color  0.003741
# 0                  cap-shape  0.000699
# 5            gill-attachment  0.000007
# 15                 veil-type  0.000000

# %%
fig, (ax) = plt.subplots(1, 1, figsize=(25,10))
sns.barplot(x=a['values'],y=a['names'],orient='h',ax=ax)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(random_state=0,max_depth=3)
clf.fit(X,Y)
print(cross_val_score(clf, X, Y, cv=10))
print("Mean Accuracy",cross_val_score(clf, X, Y, cv=10).mean())
# Out:
# [0.65928659 0.89421894 0.9901599  0.98892989 0.92487685 0.91009852
#  1.         1.         0.87438424 1.        ]
# Mean Accuracy 0.9241954931864591
